# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
# Implementation of the TextEditorTool
import os
import shutil
from typing import Optional, List


class TextEditorTool:
    def __init__(self, base_dir: str = "", backup_dir: str = ""):
        self.base_dir = base_dir or os.getcwd()
        self.backup_dir = backup_dir or os.path.join(self.base_dir, ".backups")
        os.makedirs(self.backup_dir, exist_ok=True)

    def _validate_path(self, file_path: str) -> str:
        abs_path = os.path.normpath(os.path.join(self.base_dir, file_path))
        if not abs_path.startswith(self.base_dir):
            raise ValueError(
                f"Access denied: Path '{file_path}' is outside the allowed directory"
            )
        return abs_path

    def _backup_file(self, file_path: str) -> str:
        if not os.path.exists(file_path):
            return ""
        file_name = os.path.basename(file_path)
        backup_path = os.path.join(
            self.backup_dir, f"{file_name}.{os.path.getmtime(file_path):.0f}"
        )
        shutil.copy2(file_path, backup_path)
        return backup_path

    def _restore_backup(self, file_path: str) -> str:
        file_name = os.path.basename(file_path)
        backups = [
            f for f in os.listdir(self.backup_dir) if f.startswith(file_name + ".")
        ]
        if not backups:
            raise FileNotFoundError(f"No backups found for {file_path}")

        latest_backup = sorted(backups, reverse=True)[0]
        backup_path = os.path.join(self.backup_dir, latest_backup)

        shutil.copy2(backup_path, file_path)
        return f"Successfully restored {file_path} from backup"

    def _count_matches(self, content: str, old_str: str) -> int:
        return content.count(old_str)

    def view(self, file_path: str, view_range: Optional[List[int]] = None) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if os.path.isdir(abs_path):
                try:
                    return "\n".join(os.listdir(abs_path))
                except PermissionError:
                    raise PermissionError(
                        "Permission denied. Cannot list directory contents."
                    )

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            if view_range:
                start, end = view_range
                lines = content.split("\n")

                if end == -1:
                    end = len(lines)

                selected_lines = lines[start - 1 : end]

                result = []
                for i, line in enumerate(selected_lines, start):
                    result.append(f"{i}: {line}")

                return "\n".join(result)
            else:
                lines = content.split("\n")
                result = []
                for i, line in enumerate(lines, 1):
                    result.append(f"{i}: {line}")

                return "\n".join(result)

        except UnicodeDecodeError:
            raise UnicodeDecodeError(
                "utf-8",
                b"",
                0,
                1,
                "File contains non-text content and cannot be displayed.",
            )
        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot access file.")
        except Exception as e:
            raise type(e)(str(e))

    def str_replace(self, file_path: str, old_str: str, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            match_count = self._count_matches(content, old_str)

            if match_count == 0:
                raise ValueError(
                    "No match found for replacement. Please check your text and try again."
                )
            elif match_count > 1:
                raise ValueError(
                    f"Found {match_count} matches for replacement text. Please provide more context to make a unique match."
                )

            # Create backup before modifying
            self._backup_file(abs_path)

            # Perform the replacement
            new_content = content.replace(old_str, new_str)

            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(new_content)

            return "Successfully replaced text at exactly one location."

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def create(self, file_path: str, file_text: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            # Check if file already exists
            if os.path.exists(abs_path):
                raise FileExistsError(
                    "File already exists. Use str_replace to modify it."
                )

            # Create parent directories if they don't exist
            os.makedirs(os.path.dirname(abs_path), exist_ok=True)

            # Create the file
            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(file_text)

            return f"Successfully created {file_path}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot create file.")
        except Exception as e:
            raise type(e)(str(e))

    def insert(self, file_path: str, insert_line: int, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            # Create backup before modifying
            self._backup_file(abs_path)

            with open(abs_path, "r", encoding="utf-8") as f:
                lines = f.readlines()

            # Handle line endings
            if lines and not lines[-1].endswith("\n"):
                new_str = "\n" + new_str

            # Insert at the beginning if insert_line is 0
            if insert_line == 0:
                lines.insert(0, new_str + "\n")
            # Insert after the specified line
            elif insert_line > 0 and insert_line <= len(lines):
                lines.insert(insert_line, new_str + "\n")
            else:
                raise IndexError(
                    f"Line number {insert_line} is out of range. File has {len(lines)} lines."
                )

            with open(abs_path, "w", encoding="utf-8") as f:
                f.writelines(lines)

            return f"Successfully inserted text after line {insert_line}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def undo_edit(self, file_path: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            return self._restore_backup(abs_path)

        except ValueError as e:
            raise ValueError(str(e))
        except FileNotFoundError:
            raise FileNotFoundError("No previous edits to undo")
        except PermissionError:
            raise PermissionError("Permission denied. Cannot restore file.")
        except Exception as e:
            raise type(e)(str(e))

# %%
# Process Tool Call Requests
import json

text_editor_tool = TextEditorTool()


def run_tool(tool_name, tool_input):
    if tool_name in ("str_replace_editor", "str_replace_based_edit_tool"):
        command = tool_input["command"]
        if command == "view":
            return text_editor_tool.view(
                tool_input["path"], tool_input.get("view_range")
            )
        elif command == "str_replace":
            return text_editor_tool.str_replace(
                tool_input["path"], tool_input["old_str"], tool_input["new_str"]
            )
        elif command == "create":
            return text_editor_tool.create(tool_input["path"], tool_input["file_text"])
        elif command == "insert":
            return text_editor_tool.insert(
                tool_input["path"],
                tool_input["insert_line"],
                tool_input["new_str"],
            )
        elif command == "undo_edit":
            return text_editor_tool.undo_edit(tool_input["path"])
        else:
            raise Exception(f"Unknown text editor command: {command}")
    else:
        raise Exception(f"Unknown tool name: {tool_name}")


def run_tools(message):
    tool_requests = [block for block in message.content if block.type == "tool_use"]
    tool_result_blocks = []

    for tool_request in tool_requests:
        try:
            tool_output = run_tool(tool_request.name, tool_request.input)
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": json.dumps(tool_output),
                "is_error": False,
            }
        except Exception as e:
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": f"Error: {e}",
                "is_error": True,
            }

        tool_result_blocks.append(tool_result_block)

    return tool_result_blocks

# %%
# Make the text edit schema based on the model version being used
def get_text_edit_schema(model):
    if model.startswith("claude-3-7-sonnet"):
        return {
            "type": "text_editor_20250124",
            "name": "str_replace_editor",
        }
    elif model.startswith("claude-3-5-sonnet"):
        return {
            "type": "text_editor_20241022", 
            "name": "str_replace_editor",
        }
    elif model.startswith("claude-sonnet-4-5"):
        return {
            "type": "text_editor_20250728", 
            "name": "str_replace_based_edit_tool",
        }
    else:
        return ValueError(
            f"Editor schema version not known for model: {model}"
        )

# %%
# Run the conversation in a loop until the model doesn't ask for a tool use
def run_conversation(messages):
    while True:
        response = chat(
            messages,
            tools=[get_text_edit_schema(model)],
        )

        add_assistant_message(messages, response)
        print(text_from_message(response))

        if response.stop_reason != "tool_use":
            break

        tool_results = run_tools(response)
        add_user_message(messages, tool_results)

    return messages

# %%
# Run for Reading the File Content

messages = []

add_user_message(
    messages,
    """
    Open the ./main.py file and summarize its content
    """,
)

run_conversation(messages)
# Out:
# I'll help you open and summarize the main.py file.
# ## Summary of main.py
#
# The file is very simple and contains:
#
# - **A single function** called `Greetings()` that takes no parameters
# - **Functionality**: When called, it prints the message "Hi there!" to the console
# - **Current state**: The function is defined but not called/executed in the file
#
# This appears to be a minimal Python script with a basic greeting function. The code is clean and straightforward, though the function is not currently being invoked, so running this script wouldn't produce any output.
# [{'role': 'user',
#   'content': '\n    Open the ./main.py file and summarize its content\n    '},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="I'll help you open and summarize the main.py file.", type='text'),
#    ToolUseBlock(id='toolu_019eZVUyBnGQptsy7dv8R2or', input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use', caller={'type': 'direct'})]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_019eZVUyBnGQptsy7dv8R2or',
#     'content': '"1: def Greetings():\\n2:     print(\\"Hi there!\\")"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='## Summary of main.py\n\nThe file is very simple and contains:\n\n- **A single function** called `Greetings()` that takes no parameters\n- **Functionality**: When called, it prints the message "Hi there!" to the console\n- **Current state**: The function is defined but not called/executed in the file\n\nThis appears to be a minimal Python script with a basic greeting function. The code is clean and straightforward, though the function is not currently being invoked, so running this script wouldn\'t produce any output.', type='text')]}]

# %%
# Run for Editing the File Content

messages = []

add_user_message(
    messages,
    """
    Open the ./main.py file and write out a function to calculate pi to the 5th digit.
    Then create ./test.py file to test your implementation.
    """,
)

run_conversation(messages)
# Out:
# I'll help you create a function to calculate pi to the 5th digit and then write tests for it.
#
# Now I'll add a function to calculate pi to the 5th digit. I'll use the Leibniz formula (Gregory-Leibniz series) or the more efficient Machin formula for better convergence.
# Now let's create the test file:
# Perfect! I've created both files. Let me verify what was created:
# Excellent! I've successfully created:
#
# ## **./main.py**
# Added a `calculate_pi()` function that:
# - Uses **Machin's formula** for efficient pi calculation: `π/4 = 4*arctan(1/5) - arctan(1/239)`
# - Implements the arctan function using Taylor series expansion
# - Uses Python's `Decimal` module for high precision arithmetic
# - Calculates pi to 5 decimal places by default (3.14159)
# - Can be adjusted to calculate more or fewer digits if needed
#
# ## **./test.py**
# Created comprehensive tests including:
# 1. **test_pi_5_digits()** - Verifies pi is accurate to 5 decimal places
# 2. **test_pi_different_precisions()** - Tests various precision levels (1-5 digits)
# 3. **test_pi_range()** - Ensures the result is within expected range
# 4. **test_pi_accuracy()** - Checks the absolute difference from math.pi
#
# You can run the tests with:
# ```bash
# python test.py
# ```
#
# The `calculate_pi(5)` function will return approximately **3.14159**, which is pi accurate to the 5th decimal digit!
# [{'role': 'user',
#   'content': '\n    Open the ./main.py file and write out a function to calculate pi to the 5th digit.\n    Then create ./test.py file to test your implementation.\n    '},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="I'll help you create a function to calculate pi to the 5th digit and then write tests for it.", type='text'),
#    ToolUseBlock(id='toolu_015JJV2iuLr8hu6CtxkgJfGx', input={'command': 'view', 'path': '.'}, name='str_replace_based_edit_tool', type='tool_use', caller={'type': 'direct'})]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_015JJV2iuLr8hu6CtxkgJfGx',
#     'content': '".backups\\nmain.py\\ntext_editor_tool.ipynb"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [ToolUseBlock(id='toolu_018izXnegPPws5AJ4rFy5ohj', input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use', caller={'type': 'direct'})]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_018izXnegPPws5AJ4rFy5ohj',
#     'content': '"1: def Greetings():\\n2:     print(\\"Hi there!\\")"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Now I'll add a function to calculate pi to the 5th digit. I'll use the Leibniz formula (Gregory-Leibniz series) or the more efficient Machin formula for better convergence.", type='text'),
#    ToolUseBlock(id='toolu_01EKDppt4SrXZMgVXGpND48w', input={'command': 'str_replace', 'path': './main.py', 'old_str': 'def Greetings():\n    print("Hi there!")', 'new_str': 'def Greetings():\n    print("Hi there!")\n\n\ndef calculate_pi(digits=5):\n    """\n    Calculate pi to the specified number of decimal digits using the Machin formula.\n    \n    Machin\'s formula: pi/4 = 4*arctan(1/5) - arctan(1/239)\n    \n    Args:\n        digits: Number of decimal digits to calculate (default: 5)\n    \n    Returns:\n        float: Approximation of pi to the specified precision\n    """\n    from decimal import Decimal, getcontext\n    \n    # Set precision higher than needed for accuracy\n    getcontext().prec = digits + 10\n    \n    def arctan(x, num_terms=100):\n        """Calculate arctan using Taylor series expansion"""\n        x = Decimal(x)\n        power = x\n        result = power\n        for n in range(1, num_terms):\n            power *= -x * x\n            result += power / (2 * n + 1)\n        return result\n    \n    # Machin\'s formula: pi/4 = 4*arctan(1/5) - arctan(1/239)\n    pi = 4 * (4 * arctan(Decimal(1) / Decimal(5), 100) - arctan(Decimal(1) / Decimal(239), 100))\n    \n    return float(pi)'}, name='str_replace_based_edit_tool', type='tool_use', caller={'type': 'direct'})]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01EKDppt4SrXZMgVXGpND48w',
#     'content': '"Successfully replaced text at exactly one location."',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Now let's create the test file:", type='text'),
#    ToolUseBlock(id='toolu_01DMANkD5XwVNgDkiDSwG9Kg', input={'command': 'create', 'path': './test.py', 'file_text': 'import math\nfrom main import calculate_pi\n\n\ndef test_pi_5_digits():\n    """Test that calculate_pi returns pi accurate to 5 decimal places"""\n    calculated = calculate_pi(5)\n    actual_pi = math.pi\n    \n    # Round both to 5 decimal places for comparison\n    calculated_rounded = round(calculated, 5)\n    actual_rounded = round(actual_pi, 5)\n    \n    print(f"Calculated Pi: {calculated}")\n    print(f"Actual Pi:     {actual_pi}")\n    print(f"Calculated (5 digits): {calculated_rounded}")\n    print(f"Actual (5 digits):     {actual_rounded}")\n    \n    assert calculated_rounded == actual_rounded, f"Expected {actual_rounded}, got {calculated_rounded}"\n    print("✓ Test passed: Pi calculated to 5 decimal places correctly!")\n\n\ndef test_pi_different_precisions():\n    """Test calculate_pi with different precision levels"""\n    test_cases = [\n        (1, 3.1),\n        (2, 3.14),\n        (3, 3.142),\n        (4, 3.1416),\n        (5, 3.14159),\n    ]\n    \n    print("\\nTesting different precisions:")\n    for digits, expected in test_cases:\n        calculated = calculate_pi(digits)\n        calculated_rounded = round(calculated, digits)\n        print(f"  {digits} digits: {calculated_rounded} (expected: {expected})")\n        assert calculated_rounded == expected, f"Failed for {digits} digits"\n    \n    print("✓ All precision tests passed!")\n\n\ndef test_pi_range():\n    """Test that calculated pi is within reasonable range"""\n    calculated = calculate_pi(5)\n    \n    # Pi should be between 3.14 and 3.15\n    assert 3.14 < calculated < 3.15, f"Pi {calculated} is out of expected range"\n    print("\\n✓ Range test passed!")\n\n\ndef test_pi_accuracy():\n    """Test the absolute difference between calculated and actual pi"""\n    calculated = calculate_pi(5)\n    actual_pi = math.pi\n    \n    # The difference should be very small (less than 0.00001 for 5 digits)\n    difference = abs(calculated - actual_pi)\n    print(f"\\nAbsolute difference: {difference}")\n    \n    assert difference < 0.00001, f"Difference {difference} is too large"\n    print("✓ Accuracy test passed!")\n\n\nif __name__ == "__main__":\n    print("=" * 60)\n    print("Testing Pi Calculation Function")\n    print("=" * 60)\n    \n    try:\n        test_pi_5_digits()\n        test_pi_different_precisions()\n        test_pi_range()\n        test_pi_accuracy()\n        \n        print("\\n" + "=" * 60)\n        print("ALL TESTS PASSED! ✓")\n        print("=" * 60)\n    except AssertionError as e:\n        print(f"\\n✗ Test failed: {e}")\n    except Exception as e:\n        print(f"\\n✗ Unexpected error: {e}")\n'}, name='str_replace_based_edit_tool', type='tool_use', caller={'type': 'direct'})]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01DMANkD5XwVNgDkiDSwG9Kg',
#     'content': '"Successfully created ./test.py"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Perfect! I've created both files. Let me verify what was created:", type='text'),
#    ToolUseBlock(id='toolu_012MnMZBMVLfhD6qGcmyjNhu', input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use', caller={'type': 'direct'})]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_012MnMZBMVLfhD6qGcmyjNhu',
#     'content': '"1: def Greetings():\\n2:     print(\\"Hi there!\\")\\n3: \\n4: \\n5: def calculate_pi(digits=5):\\n6:     \\"\\"\\"\\n7:     Calculate pi to the specified number of decimal digits using the Machin formula.\\n8:     \\n9:     Machin\'s formula: pi/4 = 4*arctan(1/5) - arctan(1/239)\\n10:     \\n11:     Args:\\n12:         digits: Number of decimal digits to calculate (default: 5)\\n13:     \\n14:     Returns:\\n15:         float: Approximation of pi to the specified precision\\n16:     \\"\\"\\"\\n17:     from decimal import Decimal, getcontext\\n18:     \\n19:     # Set precision higher than needed for accuracy\\n20:     getcontext().prec = digits + 10\\n21:     \\n22:     def arctan(x, num_terms=100):\\n23:         \\"\\"\\"Calculate arctan using Taylor series expansion\\"\\"\\"\\n24:         x = Decimal(x)\\n25:         power = x\\n26:         result = power\\n27:         for n in range(1, num_terms):\\n28:             power *= -x * x\\n29:             result += power / (2 * n + 1)\\n30:         return result\\n31:     \\n32:     # Machin\'s formula: pi/4 = 4*arctan(1/5) - arctan(1/239)\\n33:     pi = 4 * (4 * arctan(Decimal(1) / Decimal(5), 100) - arctan(Decimal(1) / Decimal(239), 100))\\n34:     \\n35:     return float(pi)"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Excellent! I've successfully created:\n\n## **./main.py**\nAdded a `calculate_pi()` function that:\n- Uses **Machin's formula** for efficient pi calculation: `π/4 = 4*arctan(1/5) - arctan(1/239)`\n- Implements the arctan function using Taylor series expansion\n- Uses Python's `Decimal` module for high precision arithmetic\n- Calculates pi to 5 decimal places by default (3.14159)\n- Can be adjusted to calculate more or fewer digits if needed\n\n## **./test.py**\nCreated comprehensive tests including:\n1. **test_pi_5_digits()** - Verifies pi is accurate to 5 decimal places\n2. **test_pi_different_precisions()** - Tests various precision levels (1-5 digits)\n3. **test_pi_range()** - Ensures the result is within expected range\n4. **test_pi_accuracy()** - Checks the absolute difference from math.pi\n\nYou can run the tests with:\n```bash\npython test.py\n```\n\nThe `calculate_pi(5)` function will return approximately **3.14159**, which is pi accurate to the 5th decimal digit!", type='text')]}]
